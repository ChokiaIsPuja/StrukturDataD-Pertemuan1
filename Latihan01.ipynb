# %% [markdown]
# <a href="https://colab.research.google.com/github/ChokiaIsPuja/StrukturDataD-Pertemuan1/blob/main/Latihan01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. 5 list mahasiswa

# %%
mahasiswa = ["bagas","tugus","putra","krisna","sastra"]
print("List:")
print(mahasiswa)
# Out:
# List:
# ['bagas', 'tugus', 'putra', 'krisna', 'sastra']

# %% [markdown]
# 2. tambahkan siswa

# %%
mahasiswa.append("Dekde")
print(mahasiswa)
# Out:
# ['bagas', 'tugus', 'putra', 'krisna', 'sastra', 'Dekde']

# %% [markdown]
# 3. hapus mahasiswa

# %%
mahasiswa.remove("bagas")
print(mahasiswa)
# Out:
# ['tugus', 'putra', 'krisna', 'sastra', 'Dekde']
